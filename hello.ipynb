# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# /snap/jupyter/6/lib/python3.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# IPython             argparse            importlib           runpy
# __future__          array               inspect             sched
# _abc                ast                 io                  secrets
# _ast                asynchat            ipaddress           select
# _asyncio            asyncio             ipykernel           selectors
# _bisect             asyncore            ipykernel_launcher  send2trash
# _blake2             atexit              ipython_genutils    setuptools
# _bootlocale         attr                ipywidgets          shelve
# _bz2                audioop             itertools           shlex
# _codecs             autoreload          jedi                shutil
# _codecs_cn          backcall            jinja2              signal
# _codecs_hk          base64              json                site
# _codecs_iso2022     bdb                 jsonschema          six
# _codecs_jp          binascii            jupyter             smtpd
# _codecs_kr          binhex              jupyter_client      smtplib
# _codecs_tw          bisect              jupyter_console     sndhdr
# _collections        bleach              jupyter_core        socket
# _collections_abc    builtins            keyword             socketserver
# _compat_pickle      bz2                 lib2to3             spwd
# _compression        cProfile            linecache           sqlite3
# _contextvars        calendar            locale              sre_compile
# _crypt              certifi             logging             sre_constants
# _csv                cgi                 lzma                sre_parse
# _ctypes             cgitb               macpath             ssl
# _ctypes_test        chunk               mailbox             stat
# _curses             cmath               mailcap             statistics
# _curses_panel       cmd                 markupsafe          storemagic
# _datetime           code                marshal             string
# _decimal            codecs              math                stringprep
# _dummy_thread       codeop              mimetypes           struct
# _elementtree        collections         mistune             subprocess
# _functools          colorsys            mmap                sunau
# _hashlib            compileall          modulefinder        symbol
# _heapq              concurrent          multiprocessing     sympyprinting
# _imp                configparser        nbconvert           symtable
# _io                 contextlib          nbformat            sys
# _json               contextvars         netrc               sysconfig
# _locale             copy                nis                 syslog
# _lsprof             copyreg             nntplib             tabnanny
# _lzma               crop_image          notebook            tarfile
# _markupbase         crypt               ntpath              telnetlib
# _md5                csv                 nturl2path          tempfile
# _multibytecodec     ctypes              numbers             terminado
# _multiprocessing    curses              opcode              termios
# _opcode             cythonmagic         operator            test
# _operator           dataclasses         optparse            testpath
# _osx_support        datetime            os                  tests
# _pickle             dateutil            ossaudiodev         textwrap
# _posixsubprocess    dbm                 pandocfilters       this
# _py_abc             decimal             parser              threading
# _pydecimal          decorator           parso               time
# _pyio               defusedxml          pathlib             timeit
# _pyrsistent_version detect_pitbull_nose pdb                 tkinter
# _queue              difflib             pexpect             token
# _random             dis                 pickle              tokenize
# _sha1               distutils           pickleshare         tornado
# _sha256             doctest             pickletools         trace
# _sha3               dummy_threading     pip                 traceback
# _sha512             easy_install        pipes               tracemalloc
# _signal             email               pkg_resources       traitlets
# _sitebuiltins       encodings           pkgutil             tty
# _socket             ensurepip           platform            turtle
# _sqlite3            entrypoints         plistlib            turtledemo
# _sre                enum                poplib              types
# _ssl                errno               posix               typing
# _stat               faulthandler        posixpath           unicodedata
# _string             fcntl               pprint              unittest
# _strptime           filecmp             profile             urllib
# _struct             fileinput           prometheus_client   uu
# _symtable           fnmatch             prompt_toolkit      uuid
# _sysconfigdata_aarch64_conda_cos7_linux_gnu formatter           pstats              venv
# _sysconfigdata_i686_conda_cos6_linux_gnu fractions           pty                 warnings
# _sysconfigdata_m_linux_x86_64-linux-gnu ftplib              ptyprocess          wave
# _sysconfigdata_powerpc64le_conda_cos7_linux_gnu functools           pvectorc            wcwidth
# _sysconfigdata_x86_64_apple_darwin13_4_0 gc                  pwd                 weakref
# _sysconfigdata_x86_64_conda_cos6_linux_gnu genericpath         py_compile          webbrowser
# _testbuffer         getopt              pyclbr              webencodings
# _testcapi           getpass             pydoc               wheel
# _testimportmultiple gettext             pydoc_data          widgetsnbextension
# _testmultiphase     glob                pyexpat             wsgiref
# _thread             grp                 pygments            xdrlib
# _threading_local    gzip                pyrsistent          xml
# _tkinter            hashlib             queue               xmlrpc
# _tracemalloc        heapq               quopri              xxlimited
# _warnings           hmac                random              xxsubtype
# _weakref            html                re                  zipapp
# _weakrefset         http                readline            zipfile
# _xxtestfuzz         idlelib             reprlib             zipimport
# abc                 imaplib             resource            zlib
# aifc                imghdr              rlcompleter         zmq
# antigravity         imp                 rmagic
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
# /snap/jupyter/6/lib/python3.7/pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)

# %%
height, width, abc = cameraman_img.shape
print(height, width, abc)

rotate_y_img = np.zeros((height, width), dtype=np.uint8)

for i in range(height):
    rotate_y_img[i, :] = cameraman_img[height - i - 1, :, 0]

plt.imshow(rotate_y_img, cmap="gray")
# Out:
# 256 256 3
